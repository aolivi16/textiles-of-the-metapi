# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('TEXTILE-final-csv.csv')

# %%
df
# Out:
#                                                 title  \
# 0                                    Miniature tabard
# 1                                    Textile Fragment
# 2                                               Piece
# 3                    Arkilla kunta (interior hanging)
# 4         Seasons and Elements (Summer) (set of four)
# ..                                                ...
# 85                                       Irises panel
# 86  Woman's wedding mantle (lliclla) with interlac...
# 87                                Fancy dress costume
# 88                                   Wholecloth quilt
# 89                                              Purse
#
#                                                medium           culture  \
# 0                   Cotton, camelid hair, silk, metal  Inca and Spanish
# 1   Silk, silvered (?) animal substrate wound arou...              none
# 2                                       Wool and silk              none
# ...

# %%
df.medium.value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
df.culture.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='culture'>

# %%
Department = df.department.value_counts().plot(kind = 'pie')

# %%
df['medium'].str.contains('Silk')
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
#       ...
# 85     True
# 86    False
# 87    False
# 88    False
# 89    False
# Name: medium, Length: 90, dtype: bool

# %%
Department.savefig('Deparment.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 Department.savefig('Deparment.png')
#
# AttributeError: 'Axes' object has no attribute 'savefig'

# %%
# Out:
# <Axes: xlabel='department'>
